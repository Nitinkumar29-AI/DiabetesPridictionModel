# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
import pandas as pd
import joblib
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv("C:\\Users\\Nitin\\OneDrive\\Desktop\\BTECH 2nd sem\\Diabetes_prediction_AgenticAi\\Dataset\\pima_diabetes_preprocessed.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    209.0  33.6
# 1            1     85.0           66.0           29.0     73.0  26.6
# 2            8    183.0           64.0           29.4    383.2  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# setting feature columns 
x = data.drop("Outcome",axis=1)
y = data["Outcome"]
# test train split 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# 4. Create Pipeline
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", XGBClassifier(
        n_estimators=100,
        learning_rate=0.05,
        max_depth=3,
        random_state=42
    ))
])

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
# now setting up prediction
print("Accuracy:",accuracy_score(y_test,y_pred))
print("F1 Score:",f1_score(y_test,y_pred))
print("classification report: ")
print(classification_report(y_test,y_pred))
print("Confusion Matrix: ")
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy: 0.7402597402597403
# F1 Score: 0.6428571428571429
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80        99
#            1       0.63      0.65      0.64        55
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.72      0.72       154
# weighted avg       0.74      0.74      0.74       154
#
# Confusion Matrix:
# [[78 21]
#  [19 36]]
